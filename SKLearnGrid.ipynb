# %%
import pandas as pd
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/poker/poker-hand-training-true.data",names=["S1","C1","S2","C2","S3","C3","S4","C4","S5","C5","Class"])
df
# Out:
#        S1  C1  S2  C2  S3  C3  S4  C4  S5  C5  Class
# 0       1  10   1  11   1  13   1  12   1   1      9
# 1       2  11   2  13   2  10   2  12   2   1      9
# 2       3  12   3  11   3  13   3  10   3   1      9
# 3       4  10   4  11   4   1   4  13   4  12      9
# 4       4   1   4  13   4  12   4  11   4  10      9
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ..    ...
# 25005   3   9   2   6   4  11   4  12   2   4      0
# 25006   4   1   4  10   3  13   3   4   1  10      1
# 25007   2   1   2  10   4   4   4   1   4  13      1
# 25008   2  12   4   3   1  10   1  12   4   9      1
# 25009   1   7   3  11   3   3   4   8   3   7      1
#
# [25010 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df, df.Class, test_size=0.25, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
tuned_parameters=[{"max_depth":[5,10,15],"min_samples_leaf":[2,3,5],"max_features":[8,9,10],"min_samples_split":[2,3,4]}]
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, cv=26,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'max_depth': 15, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 3}
#
# Grid scores on development set:
#
# 0.578 (+/-0.248) for {'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.602 (+/-0.239) for {'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 3}
# 0.654 (+/-0.253) for {'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.615 (+/-0.251) for {'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.632 (+/-0.281) for {'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.578 (+/-0.217) for {'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.634 (+/-0.320) for {'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 2}
# ...

# %%
from sklearn.neural_network import MLPClassifier
import numpy 
tuned_parameters={'activation':['relu'],'alpha': 10.0 ** -numpy.arange(3,4,5), 'hidden_layer_sizes':numpy.arange(23, 26), 'random_state':[0,1,2,3]}
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(MLPClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 24, 'random_state': 0}
#
# Grid scores on development set:
#
# 0.673 (+/-0.150) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 23, 'random_state': 0}
# 0.688 (+/-0.121) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 23, 'random_state': 1}
# 0.685 (+/-0.154) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 23, 'random_state': 2}
# 0.666 (+/-0.108) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 23, 'random_state': 3}
# 0.694 (+/-0.091) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 24, 'random_state': 0}
# 0.687 (+/-0.094) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 24, 'random_state': 1}
# 0.654 (+/-0.113) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 24, 'random_state': 2}
# ...

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB(priors=None)
gnb.fit(x_train, y_train)
predictions=gnb.predict(x_test)
from sklearn import metrics
print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3138
#            1       1.00      1.00      1.00      2623
#            2       1.00      1.00      1.00       315
#            3       1.00      1.00      1.00       125
#            4       1.00      1.00      1.00        28
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         1
#            9       1.00      1.00      1.00         1
#
#     accuracy                           1.00      6253
#    macro avg       1.00      1.00      1.00      6253
# weighted avg       1.00      1.00      1.00      6253

# %%
from sklearn.svm import SVC
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000],'random_state':[0,1,2]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000],'random_state':[0,1,2]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 0}
#
# Grid scores on development set:
#
# 0.283 (+/-0.054) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 0}
# 0.283 (+/-0.054) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 1}
# 0.283 (+/-0.054) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 2}
# 0.194 (+/-0.037) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 0}
# 0.194 (+/-0.037) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 1}
# 0.194 (+/-0.037) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 2}
# 0.531 (+/-0.076) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 0}
# 0.531 (+/-0.076) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 1}
# 0.531 (+/-0.076) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 2}
# ...

# %%
from sklearn.linear_model import LogisticRegression
import numpy
tuned_parameters=[{'C':10.0 ** -numpy.arange(3,4,5),'fit_intercept':[True,False],'penalty':['l1','l2'],'multi_class':['ovr']}]
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(LogisticRegression(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'C': 0.001, 'fit_intercept': True, 'multi_class': 'ovr', 'penalty': 'l1'}
#
# Grid scores on development set:
#
# 0.194 (+/-0.037) for {'C': 0.001, 'fit_intercept': True, 'multi_class': 'ovr', 'penalty': 'l1'}
# 0.194 (+/-0.037) for {'C': 0.001, 'fit_intercept': True, 'multi_class': 'ovr', 'penalty': 'l2'}
# 0.194 (+/-0.037) for {'C': 0.001, 'fit_intercept': False, 'multi_class': 'ovr', 'penalty': 'l1'}
# 0.194 (+/-0.037) for {'C': 0.001, 'fit_intercept': False, 'multi_class': 'ovr', 'penalty': 'l2'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3138
#            1       0.84      1.00      0.91      2623
#            2       0.00      0.00      0.00       315
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

tuned_parameters=[{'n_neighbors':[3,4,5],'weights':['uniform','distance'],'algorithm':['kd_tree','ball_tree','brute'],'p':[1,2]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'algorithm': 'kd_tree', 'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.474 (+/-0.188) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.492 (+/-0.159) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.350 (+/-0.155) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.393 (+/-0.077) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.492 (+/-0.109) for {'algorithm': 'kd_tree', 'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
# 0.519 (+/-0.105) for {'algorithm': 'kd_tree', 'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
# 0.337 (+/-0.128) for {'algorithm': 'kd_tree', 'n_neighbors': 4, 'p': 2, 'weights': 'uniform'}
# 0.369 (+/-0.108) for {'algorithm': 'kd_tree', 'n_neighbors': 4, 'p': 2, 'weights': 'distance'}
# ...

# %%
from sklearn.ensemble import BaggingClassifier
tuned_parameters=[{'n_estimators':[8,10,12],'max_samples':[1,5,10],'max_features':[8,9,10],'random_state':[0,1,2,3]}]
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(BaggingClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'max_features': 8, 'max_samples': 10, 'n_estimators': 8, 'random_state': 2}
#
# Grid scores on development set:
#
# 0.048 (+/-0.009) for {'max_features': 8, 'max_samples': 1, 'n_estimators': 8, 'random_state': 0}
# 0.051 (+/-0.003) for {'max_features': 8, 'max_samples': 1, 'n_estimators': 8, 'random_state': 1}
# 0.052 (+/-0.010) for {'max_features': 8, 'max_samples': 1, 'n_estimators': 8, 'random_state': 2}
# 0.049 (+/-0.015) for {'max_features': 8, 'max_samples': 1, 'n_estimators': 8, 'random_state': 3}
# 0.048 (+/-0.009) for {'max_features': 8, 'max_samples': 1, 'n_estimators': 10, 'random_state': 0}
# 0.049 (+/-0.007) for {'max_features': 8, 'max_samples': 1, 'n_estimators': 10, 'random_state': 1}
# 0.052 (+/-0.010) for {'max_features': 8, 'max_samples': 1, 'n_estimators': 10, 'random_state': 2}
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
tuned_parameters=[{'n_estimators':[10,50,100],'criterion':['gini','entropy'],'max_depth':[10,50,100],'max_features':[8,9,10]}]
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, cv=15,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 10, 'max_features': 10, 'n_estimators': 50}
#
# Grid scores on development set:
#
# 0.929 (+/-0.184) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 8, 'n_estimators': 10}
# 0.964 (+/-0.150) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 8, 'n_estimators': 50}
# 0.944 (+/-0.194) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 8, 'n_estimators': 100}
# 0.948 (+/-0.183) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 9, 'n_estimators': 10}
# 0.964 (+/-0.147) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 9, 'n_estimators': 50}
# 0.963 (+/-0.156) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 9, 'n_estimators': 100}
# 0.970 (+/-0.120) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 10, 'n_estimators': 10}
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier
tuned_parameters=[{'n_estimators':[10,50,100],'learning_rate':10.0**-numpy.arange(2,4),'algorithm':['SAMME', 'SAMME.R'],'random_state':[0,1,2,3,4]}]
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(AdaBoostClassifier(), tuned_parameters, cv=15,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'algorithm': 'SAMME.R', 'learning_rate': 0.01, 'n_estimators': 100, 'random_state': 0}
#
# Grid scores on development set:
#
# 0.241 (+/-0.070) for {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 10, 'random_state': 0}
# 0.241 (+/-0.070) for {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 10, 'random_state': 1}
# 0.241 (+/-0.070) for {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 10, 'random_state': 2}
# 0.241 (+/-0.070) for {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 10, 'random_state': 3}
# 0.241 (+/-0.070) for {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 10, 'random_state': 4}
# 0.241 (+/-0.070) for {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 50, 'random_state': 0}
# 0.241 (+/-0.070) for {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 50, 'random_state': 1}
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
tuned_parameters=[{'n_estimators':[50,100],'loss':['deviance'],'max_depth':[5,10],'max_features':[5,10]}]
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(GradientBoostingClassifier(), tuned_parameters, cv=15,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'loss': 'deviance', 'max_depth': 5, 'max_features': 10, 'n_estimators': 50}
#
# Grid scores on development set:
#
# 0.900 (+/-0.223) for {'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 50}
# 0.901 (+/-0.378) for {'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 100}
# 0.993 (+/-0.050) for {'loss': 'deviance', 'max_depth': 5, 'max_features': 10, 'n_estimators': 50}
# 0.983 (+/-0.087) for {'loss': 'deviance', 'max_depth': 5, 'max_features': 10, 'n_estimators': 100}
# 0.938 (+/-0.156) for {'loss': 'deviance', 'max_depth': 10, 'max_features': 5, 'n_estimators': 50}
# 0.920 (+/-0.200) for {'loss': 'deviance', 'max_depth': 10, 'max_features': 5, 'n_estimators': 100}
# 0.967 (+/-0.145) for {'loss': 'deviance', 'max_depth': 10, 'max_features': 10, 'n_estimators': 50}
# ...

# %%
from xgboost import XGBClassifier
tuned_parameters=[{'n_estimators':[50,100],'booster':['gbtree','gblinear'],'learning_rate':10.0**-numpy.arange(2,4),'min_child_weight':[1,2]}]
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(XGBClassifier(), tuned_parameters, cv=10,
                       scoring='%s_macro' % score)
    clf.fit(x_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'booster': 'gbtree', 'learning_rate': 0.01, 'min_child_weight': 1, 'n_estimators': 100}
#
# Grid scores on development set:
#
# 0.940 (+/-0.147) for {'booster': 'gbtree', 'learning_rate': 0.01, 'min_child_weight': 1, 'n_estimators': 50}
# 1.000 (+/-0.000) for {'booster': 'gbtree', 'learning_rate': 0.01, 'min_child_weight': 1, 'n_estimators': 100}
# 0.916 (+/-0.217) for {'booster': 'gbtree', 'learning_rate': 0.01, 'min_child_weight': 2, 'n_estimators': 50}
# 0.916 (+/-0.217) for {'booster': 'gbtree', 'learning_rate': 0.01, 'min_child_weight': 2, 'n_estimators': 100}
# 0.940 (+/-0.147) for {'booster': 'gbtree', 'learning_rate': 0.001, 'min_child_weight': 1, 'n_estimators': 50}
# 0.940 (+/-0.147) for {'booster': 'gbtree', 'learning_rate': 0.001, 'min_child_weight': 1, 'n_estimators': 100}
# ...
